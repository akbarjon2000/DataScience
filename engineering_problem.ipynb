# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarjon2000/DataScience/blob/main/engineering_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
t = [0.]
v = [1.]
d = [0.]
dt= 0.01

# %%
def velocity(t):
  return np.cos(t)

# %%
def displacement(y):
  return -np.sin(y)

# %%
for i in range(1000):
  t.append(t[-1]+ dt)
  v.append(v[-1] + velocity(t[-1]) * dt)
  d.append(d[-1] + v[-1]* dt)

# %%
plt.plot(t, v)
plt.plot(t, d, "r-")

# %%
#second

# %%
def a(y,v, m = 10, k = 90, c=10):
  return -(k/m)*y + (c/m)*v

# %%
dt = 0.01
t = [0.]
v = [0.]
d = [1.]
dt = 0.01

# %%
for i in range(1000):
  t.append(t[-1]+ dt)
  v.append(v[-1] + a(d[-1], v[-1]) *dt)
  d.append(d[-1] + v[-1]*dt)

# %%
plt.plot(v)
