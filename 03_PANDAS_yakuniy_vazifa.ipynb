# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarjon2000/DataScience/blob/main/03_PANDAS_yakuniy_vazifa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# ### PANDAS. Yakuniy vazifa. **1-QISM**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population.csv", index_col=0)
df
# Out:
#                country     density   densityMi   pop2021     area
# rank
# 1                Macau  21946.4667  56841.3487   658.394       30
# 2               Monaco  19755.5000  51166.7450    39.511        2
# 3            Singapore   8305.1915  21510.4461  5896.686      710
# 4            Hong Kong   6841.3134  17719.0017  7552.810     1104
# 5            Gibraltar   5616.3333  14546.3033    33.698        6
# ...                ...         ...         ...       ...      ...
# 228            Namibia      3.1338      8.1166  2587.344   825615
# 229     Western Sahara      2.3003      5.9577   611.875   266000
# 230           Mongolia      2.1286      5.5129  3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517     3.533    12173
# 232          Greenland      0.0263      0.0680    56.877  2166086
#
# [232 rows x 5 columns]

# %% [markdown]
# ### 1-VAZIFA. Yuqoridagi DF ustunlari nomini quyidagi qiymatlarga o'zgartiring va DF yuqorisidan 3 ta davlatni chiqaring
# `['davlat','zichlik_km','zichlik_mi','aholi','maydoni']`

# %%
# JAVOBNI SHUYERGA YOZING
df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df.head(3)
# Out:
#          davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1         Macau  21946.4667  56841.3487   658.394       30
# 2        Monaco  19755.5000  51166.7450    39.511        2
# 3     Singapore   8305.1915  21510.4461  5896.686      710

# %%
#@title To'g'ri javob
df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df.head(3)
# Out:
#          davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1         Macau  21946.4667  56841.3487   658.394       30
# 2        Monaco  19755.5000  51166.7450    39.511        2
# 3     Singapore   8305.1915  21510.4461  5896.686      710

# %% [markdown]
# ## Yuqoridagi jadval dunyo davlatlarining aholi zichligi bo'yicha reytingini ko'rsatadi.
# DF indeksi sifatida davlatning zichlik reytingi olingan (aholi eng zich yashaydigan davlatlar yuqorida).
#
# **Ustunlar:**
#
# `davlat` - Davlat nomi
#
# `zichlik_km` - har 1 kv.km. ga to'g'ri keluvchi aholi soni
#
# `zichlik_mi` - har 1 kv.milyaga to'g'ri keluvchi aholi soni (milya - AQSh masofa o'lchov birligi)
#
# `aholi` - 2021-yilga ko'rsa aholi soni (ming)
#
# `maydoni` - davlat maydoni (kv.km)

# %% [markdown]
# ### 2-VAZIFA. DF oxiridan 10 ta qator chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df.tail(10)
# Out:
#                 davlat  zichlik_km  zichlik_mi      aholi  maydoni
# rank
# 223             Guyana      3.6765      9.5220    790.326   214969
# 224      French Guiana      3.6685      9.5015    306.448    83534
# 225           Suriname      3.6125      9.3564    591.800   163820
# 226          Australia      3.3526      8.6832  25788.215  7692024
# 227            Iceland      3.3335      8.6338    343.353   103000
# 228            Namibia      3.1338      8.1166   2587.344   825615
# 229     Western Sahara      2.3003      5.9577    611.875   266000
# 230           Mongolia      2.1286      5.5129   3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517      3.533    12173
# 232          Greenland      0.0263      0.0680     56.877  2166086

# %% [markdown]
# ### 3-VAZIFA. DF dan 10, 20, 100, 200-indekslarda turgan davlatlarni alohida DF ko'rinishida chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
d1 = pd.DataFrame(df.loc[10]).T
d1 = d1.append(df.loc[20])
d1 = d1.append(df.loc[100])
d1 = d1.append(df.loc[200])
d1
# Out:
# <ipython-input-33-be1a3a3dc186>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   d1 = d1.append(df.loc[20])
# <ipython-input-33-be1a3a3dc186>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   d1 = d1.append(df.loc[100])
# <ipython-input-33-be1a3a3dc186>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   d1 = d1.append(df.loc[200])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     553         try:
# --> 554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
#
# KeyError: 10
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-be1a3a3dc186> in <cell line: 7>()
#       5 d1 = d1.append(df.loc[200])
#       6 d1
# ----> 7 d1.loc(10).append(d1.loc(20))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __call__(self, axis)
#     666
#     667         if axis is not None:
# --> 668             axis = self.obj._get_axis_number(axis)
#     669         new_self.axis = axis
#     670         return new_self
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
# --> 556             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     557
#     558     @final
#
# ValueError: No axis named 10 for object type DataFrame

# %% [markdown]
# ### 4-VAZIFA. Davlatlar orasida `Uzbekistan`, `Hong-Kong`, `Antartica` borligini tekshiring

# %%
# JAVOBNI SHUYERGA YOZING
df[df.davlat.isin(["Uzbekistan", "Hong-Kong", "Antartica"])==True]
# Out:
#           davlat  zichlik_km  zichlik_mi      aholi  maydoni
# rank
# 133   Uzbekistan     75.8511    196.4542  33935.763   447400

# %% [markdown]
# ### 5-VAZIFA.
# #### 5.1 DFning `davlat` nomli ustunini uning indeksi qilib belgilang.
# #### 5.2 `davlat` ustunini tashlab yuboring.
# #### 5.3 DFni davlat nomi bo'yicha tartiblang

# %%
# JAVOBNI SHUYERGA YOZING
df.index = df.davlat
df.drop('davlat', axis=1)
df.sort_index()
# Out:
#                               davlat  zichlik_km  zichlik_mi      aholi  \
# davlat
# Afghanistan              Afghanistan     61.0757    158.1862  39835.428
# Albania                      Albania     99.9351    258.8318   2872.933
# Algeria                      Algeria     18.7328     48.5179  44616.624
# American Samoa        American Samoa    276.8844    717.1307     55.100
# Andorra                      Andorra    165.2885    428.0971     77.355
# ...                              ...         ...         ...        ...
# Wallis and Futuna  Wallis and Futuna     78.1268    202.3483     11.094
# Western Sahara        Western Sahara      2.3003      5.9577    611.875
# Yemen                          Yemen     57.7509    149.5749  30490.640
# Zambia                        Zambia     25.1400     65.1125  18920.651
# Zimbabwe                    Zimbabwe     38.6229    100.0333  15092.171
#
#                    maydoni
# davlat
# Afghanistan         652230
# Albania              28748
# Algeria            2381741
# American Samoa         199
# Andorra                468
# ...                    ...
# Wallis and Futuna      142
# Western Sahara      266000
# Yemen               527968
# Zambia              752612
# Zimbabwe            390757
#
# [232 rows x 5 columns]

# %%
#@title Kutilayotgan natija
# Out:
#                 zichlik_km  zichlik_mi      aholi  maydoni
# davlat
# Afghanistan        61.0757    158.1862  39835.428   652230
# Albania            99.9351    258.8318   2872.933    28748
# Algeria            18.7328     48.5179  44616.624  2381741
# American Samoa    276.8844    717.1307     55.100      199
# Andorra           165.2885    428.0971     77.355      468

# %% [markdown]
# ### 6-VAZIFA. DF dan `Uzbekistan`, `Malaysia`, `South Korea`, `France` davlatlari `aholi` va `maydoni` ustunlari bilan alohida DF ko'rinishida ajratib oling.

# %%
# JAVOBNI SHUYERGA YOZING
d1 = df[df.index.isin(['Uzbekistan', 'Malaysia', 'South Korea', 'France'])]
d1
# Out:
#                   davlat  zichlik_km  zichlik_mi      aholi  maydoni
# davlat
# South Korea  South Korea    511.9767   1326.0197  51305.186   100210
# France            France    118.5912    307.1512  65426.179   551695
# Malaysia        Malaysia     99.0807    256.6190  32776.194   330803
# Uzbekistan    Uzbekistan     75.8511    196.4542  33935.763   447400

# %%
#@title O'xshash natija (boshqa davlatlar uchun)
# Out:
#                  aholi  maydoni
# davlat
# Singapore     5896.686      710
# North Korea  25887.041   120538
# Germany      83900.473   357114
# Kazakhstan   18994.962  2724900

# %% [markdown]
# ### 7-VAZIFA. Asl DFning `aholi` ustuni qiymatlarini 1000 ga ko'paytiring.

# %%
# JAVOBNI SHUYERGA YOZING
df.aholi = df.aholi * 1000
df
# Out:
#                             davlat  zichlik_km  zichlik_mi         aholi  \
# davlat
# Macau                        Macau  21946.4667  56841.3487  6.583940e+08
# Monaco                      Monaco  19755.5000  51166.7450  3.951100e+07
# Singapore                Singapore   8305.1915  21510.4461  5.896686e+09
# Hong Kong                Hong Kong   6841.3134  17719.0017  7.552810e+09
# Gibraltar                Gibraltar   5616.3333  14546.3033  3.369800e+07
# ...                            ...         ...         ...           ...
# Namibia                    Namibia      3.1338      8.1166  2.587344e+09
# Western Sahara      Western Sahara      2.3003      5.9577  6.118750e+08
# Mongolia                  Mongolia      2.1286      5.5129  3.329289e+09
# Falkland Islands  Falkland Islands      0.2902      0.7517  3.533000e+06
# Greenland                Greenland      0.0263      0.0680  5.687700e+07
#
#                   maydoni
# davlat
# Macau                  30
# Monaco                  2
# Singapore             710
# Hong Kong            1104
# Gibraltar               6
# ...                   ...
# Namibia            825615
# Western Sahara     266000
# Mongolia          1564110
# Falkland Islands    12173
# Greenland         2166086
#
# [232 rows x 5 columns]

# %%
#@title Kutilgan natija
# Out:
#                 zichlik_km  zichlik_mi       aholi  maydoni
# davlat
# Afghanistan        61.0757    158.1862  39835428.0   652230
# Albania            99.9351    258.8318   2872933.0    28748
# Algeria            18.7328     48.5179  44616624.0  2381741
# American Samoa    276.8844    717.1307     55100.0      199
# Andorra           165.2885    428.0971     77355.0      468

# %% [markdown]
# DF ni `aholi` ustuni bo'yicha kamayish tartibida tahlang va aholisi eng kam 10 ta davlatni chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df.sort_values(by="aholi", ascending=False)
df.tail(10)
# Out:
#                             davlat  zichlik_km  zichlik_mi         aholi  \
# davlat
# Guyana                      Guyana      3.6765      9.5220  7.903260e+08
# French Guiana        French Guiana      3.6685      9.5015  3.064480e+08
# Suriname                  Suriname      3.6125      9.3564  5.918000e+08
# Australia                Australia      3.3526      8.6832  2.578822e+10
# Iceland                    Iceland      3.3335      8.6338  3.433530e+08
# Namibia                    Namibia      3.1338      8.1166  2.587344e+09
# Western Sahara      Western Sahara      2.3003      5.9577  6.118750e+08
# Mongolia                  Mongolia      2.1286      5.5129  3.329289e+09
# Falkland Islands  Falkland Islands      0.2902      0.7517  3.533000e+06
# Greenland                Greenland      0.0263      0.0680  5.687700e+07
#
#                   maydoni
# davlat
# Guyana             214969
# French Guiana       83534
# Suriname           163820
# Australia         7692024
# Iceland            103000
# Namibia            825615
# Western Sahara     266000
# Mongolia          1564110
# Falkland Islands    12173
# Greenland         2166086

# %% [markdown]
# ### 8-VAZIFA. DFni `maydoni` bo'yicha reytinglang (rank) va reytinglarni yangi `rank` ustuniga yozing.

# %%
# JAVOBNI SHUYERGA YOZING
df['rank'] = df['maydoni'].rank()
df
# Out:
#                             davlat  zichlik_km  zichlik_mi         aholi  \
# davlat
# Macau                        Macau  21946.4667  56841.3487  6.583940e+08
# Monaco                      Monaco  19755.5000  51166.7450  3.951100e+07
# Singapore                Singapore   8305.1915  21510.4461  5.896686e+09
# Hong Kong                Hong Kong   6841.3134  17719.0017  7.552810e+09
# Gibraltar                Gibraltar   5616.3333  14546.3033  3.369800e+07
# ...                            ...         ...         ...           ...
# Namibia                    Namibia      3.1338      8.1166  2.587344e+09
# Western Sahara      Western Sahara      2.3003      5.9577  6.118750e+08
# Mongolia                  Mongolia      2.1286      5.5129  3.329289e+09
# Falkland Islands  Falkland Islands      0.2902      0.7517  3.533000e+06
# Greenland                Greenland      0.0263      0.0680  5.687700e+07
#
#                   maydoni   rank
# davlat
# Macau                  30    8.0
# Monaco                  2    2.0
# Singapore             710   43.0
# Hong Kong            1104   50.0
# Gibraltar               6    3.0
# ...                   ...    ...
# Namibia            825615  198.0
# Western Sahara     266000  155.0
# Mongolia          1564110  214.0
# Falkland Islands    12173   70.0
# Greenland         2166086  221.0
#
# [232 rows x 6 columns]

# %%
#@title Kutilgan natija
# Out:
#                    zichlik_km  zichlik_mi       aholi  maydoni   rank
# davlat
# Afghanistan           61.0757    158.1862  39835428.0   652230  192.0
# Albania               99.9351    258.8318   2872933.0    28748   89.0
# Algeria               18.7328     48.5179  44616624.0  2381741  223.0
# American Samoa       276.8844    717.1307     55100.0      199   20.0
# Andorra              165.2885    428.0971     77355.0      468   38.0
# ...                       ...         ...         ...      ...    ...
# Wallis and Futuna     78.1268    202.3483     11094.0      142   15.0
# Western Sahara         2.3003      5.9577    611875.0   266000  155.0
# Yemen                 57.7509    149.5749  30490640.0   527968  183.0
# Zambia                25.1400     65.1125  18920651.0   752612  194.0
# Zimbabwe              38.6229    100.0333  15092171.0   390757  172.0
#
# [232 rows x 5 columns]

# %% [markdown]
# #### `Uzbekistan`, `United Kingdom`, `Indonesia` davlatlari alohida df ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
df[df.index.isin(["Uzbekistan", "United Kingdom", "Indonesia"])]
# Out:
#                         davlat  zichlik_km  zichlik_mi         aholi  maydoni  \
# davlat
# United Kingdom  United Kingdom    280.8033    727.2805  6.820712e+10   242900
# Indonesia            Indonesia    145.1046    375.8210  2.763618e+11  1904569
# Uzbekistan          Uzbekistan     75.8511    196.4542  3.393576e+10   447400
#
#                  rank
# davlat
# United Kingdom  153.0
# Indonesia       218.0
# Uzbekistan      176.0

# %%
#@title O'xshash natija (boshqa davlatlar uchun)
# Out:
#                zichlik_km  zichlik_mi        aholi  maydoni   rank
# davlat
# Turkmenistan      12.5342     32.4635    6117924.0   488100  180.0
# United States     35.5200     91.9968  332915073.0  9372610  229.0
# Vietnam          296.3927    767.6572   98168833.0   331212  166.0

# %% [markdown]
# ### 9-VAZIFA. DFni `davlat` nomi bo'yicha tartiblang.

# %%
# JAVOBNI SHUYERGA YOZING
df.sort_index()
# Out:
#                               davlat  zichlik_km  zichlik_mi         aholi  \
# davlat
# Afghanistan              Afghanistan     61.0757    158.1862  3.983543e+10
# Albania                      Albania     99.9351    258.8318  2.872933e+09
# Algeria                      Algeria     18.7328     48.5179  4.461662e+10
# American Samoa        American Samoa    276.8844    717.1307  5.510000e+07
# Andorra                      Andorra    165.2885    428.0971  7.735500e+07
# ...                              ...         ...         ...           ...
# Wallis and Futuna  Wallis and Futuna     78.1268    202.3483  1.109400e+07
# Western Sahara        Western Sahara      2.3003      5.9577  6.118750e+08
# Yemen                          Yemen     57.7509    149.5749  3.049064e+10
# Zambia                        Zambia     25.1400     65.1125  1.892065e+10
# Zimbabwe                    Zimbabwe     38.6229    100.0333  1.509217e+10
#
#                    maydoni   rank
# davlat
# Afghanistan         652230  192.0
# Albania              28748   89.0
# Algeria            2381741  223.0
# American Samoa         199   20.0
# Andorra                468   38.0
# ...                    ...    ...
# Wallis and Futuna      142   15.0
# Western Sahara      266000  155.0
# Yemen               527968  183.0
# Zambia              752612  194.0
# Zimbabwe            390757  172.0
#
# [232 rows x 6 columns]

# %%
#@title Kutilgan natija
# Out:
#                 zichlik_km  zichlik_mi       aholi  maydoni   rank
# davlat
# Afghanistan        61.0757    158.1862  39835428.0   652230  192.0
# Albania            99.9351    258.8318   2872933.0    28748   89.0
# Algeria            18.7328     48.5179  44616624.0  2381741  223.0
# American Samoa    276.8844    717.1307     55100.0      199   20.0
# Andorra           165.2885    428.0971     77355.0      468   38.0

# %% [markdown]
# #### DFdan 10,50,100,200-o'rinda turgan davlatlarni alohida DF ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZI]
df.iloc[[10, 20,100, 200]]
# Out:
#                 davlat  zichlik_km  zichlik_mi         aholi  maydoni   rank
# davlat
# Bangladesh  Bangladesh   1126.9465   2918.7915  1.663035e+11   147570  139.0
# San Marino  San Marino    557.6557   1444.3284  3.401700e+07       61   12.0
# Benin            Benin    110.5560    286.3401  1.245104e+10   112622  131.0
# Paraguay      Paraguay     17.7495     45.9712  7.219638e+09   406752  173.0

# %%
#@title O'xshash natija (boshqa qatorlar uchun)
# Out:
#                               zichlik_km  zichlik_mi     aholi  maydoni  rank
# davlat
# Belize                           17.6310     45.6643  404914.0    22966  82.0
# French Polynesia                 67.8018    175.6066  282530.0     4167  60.0
# Guadeloupe                      245.7125    636.3955  400020.0     1628  53.0
# United States Virgin Islands    300.3631    777.9405  104226.0      347  29.0

# %% [markdown]
# ### 10-VAZIFA. Quyidagi davlatlarning `aholi` sonini oddiy son ko'rinishida chiqaring:
# - `Malaysia`
# - `Nigeria`
# - `Nepal`
# - `Italy`

# %%
# JAVOBNI SHUYERGA YOZING
df.aholi[['Malaysia', 'Nigeria', 'Nepal', 'Italy']]
# Out:
# davlat
# Malaysia    3.277619e+10
# Nigeria     2.114007e+11
# Nepal       2.967492e+10
# Italy       6.036748e+10
# Name: aholi, dtype: float64

# %%
#@title o'xshash natija (`Uzbekistan` uchun)
# Out:
# 33935763.0
