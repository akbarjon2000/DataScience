# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarjon2000/DataScience/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Section 1 Homework

# %%
import numpy as np

# %%
weights = [-0.5, 0.5, 1]

# %%
input = [10, 15, 1]

# %%
def feedforward(weights, input):
    sum = 0
    for i in range(len(weights)):
        sum += weights[i] * input[i]
    return activatetor(sum)

# %%
def activatetor(sum):
    if sum > 0:
        return 1
    else:
        return -1

# %%
feedforward(weights, input)
# Out:
# 1

# %% [markdown]
# Section 2 Homework

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
data_link = "https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt"
col_names = ["variance", "skewness", "curtosis", "entropy", "class"]

bankdata = pd.read_csv(data_link, names=col_names, sep=",", header=None)
bankdata.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
X_train, X_test, y_train, y_test = train_test_split(bankdata.drop("class", axis=1), bankdata["class"], test_size=0.2)

# %% [markdown]
# Linear Kernel

# %%
svclassifier = SVC(kernel="linear")
svclassifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svclassifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[162   3]
#  [  0 110]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       165
#            1       0.97      1.00      0.99       110
#
#     accuracy                           0.99       275
#    macro avg       0.99      0.99      0.99       275
# weighted avg       0.99      0.99      0.99       275

# %% [markdown]
# Poly Kernel

# %%
svclassifier = SVC(kernel="poly", degree=8)
svclassifier.fit(X_train, y_train)
# Out:
# SVC(degree=8, kernel='poly')

# %%
y_pred = svclassifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 95  70]
#  [  0 110]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.58      0.73       165
#            1       0.61      1.00      0.76       110
#
#     accuracy                           0.75       275
#    macro avg       0.81      0.79      0.74       275
# weighted avg       0.84      0.75      0.74       275

# %% [markdown]
# RBF Kernel

# %%
svclassifier = SVC(kernel = "rbf", gamma=0.008, C = 0.1, random_state=1)
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=0.1, gamma=0.008, random_state=1)

# %%
y_pred = svclassifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[158   7]
#  [  0 110]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       165
#            1       0.94      1.00      0.97       110
#
#     accuracy                           0.97       275
#    macro avg       0.97      0.98      0.97       275
# weighted avg       0.98      0.97      0.97       275
