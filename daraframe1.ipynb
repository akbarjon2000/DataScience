# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarjon2000/DataScience/blob/main/daraframe1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    "yil":[2021, 2020, 2019, 2022, 2023, 2009,2012],
    "Aholi soni":[30.1, 32.4, 45.6, 98.5, 22.4,534.5, 67.2],
    "temp":[2.3,4.1,42.3,5.1,4.5,5.6,7.2]
}

# %%
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     yil  Aholi soni  temp
# 0  2021        30.1   2.3
# 1  2020        32.4   4.1
# 2  2019        45.6  42.3
# 3  2022        98.5   5.1
# 4  2023        22.4   4.5
# 5  2009       534.5   5.6
# 6  2012        67.2   7.2

# %%
frame.head()
# Out:
#     yil  Aholi soni  temp
# 0  2021        30.1   2.3
# 1  2020        32.4   4.1
# 2  2019        45.6  42.3
# 3  2022        98.5   5.1
# 4  2023        22.4   4.5

# %%
frame.head(4)
# Out:
#     yil  Aholi soni  temp
# 0  2021        30.1   2.3
# 1  2020        32.4   4.1
# 2  2019        45.6  42.3
# 3  2022        98.5   5.1

# %%
frame = pd.DataFrame(data, columns = ["temp", "yil", "Aholi soni"])

# %%
frame
# Out:
#    temp   yil  Aholi soni
# 0   2.3  2021        30.1
# 1   4.1  2020        32.4
# 2  42.3  2019        45.6
# 3   5.1  2022        98.5
# 4   4.5  2023        22.4
# 5   5.6  2009       534.5
# 6   7.2  2012        67.2

# %%
frame.head()
# Out:
#    temp   yil  Aholi soni
# 0   2.3  2021        30.1
# 1   4.1  2020        32.4
# 2  42.3  2019        45.6
# 3   5.1  2022        98.5
# 4   4.5  2023        22.4

# %%
frame.head(3)
# Out:
#    temp   yil  Aholi soni
# 0   2.3  2021        30.1
# 1   4.1  2020        32.4
# 2  42.3  2019        45.6

# %%
frame = pd.DataFrame(data, columns = ['temp', 'yil', 'Aholi soni', 'unknown'])

# %%
frame
# Out:
#    temp   yil  Aholi soni unknown
# 0   2.3  2021        30.1     NaN
# 1   4.1  2020        32.4     NaN
# 2  42.3  2019        45.6     NaN
# 3   5.1  2022        98.5     NaN
# 4   4.5  2023        22.4     NaN
# 5   5.6  2009       534.5     NaN
# 6   7.2  2012        67.2     NaN

# %%
frame['unknown'] = 111

# %%
frame
# Out:
#    temp   yil  Aholi soni  unknown
# 0   2.3  2021        30.1      111
# 1   4.1  2020        32.4      111
# 2  42.3  2019        45.6      111
# 3   5.1  2022        98.5      111
# 4   4.5  2023        22.4      111
# 5   5.6  2009       534.5      111
# 6   7.2  2012        67.2      111

# %%
frame.unknown = 222

# %%
frame
# Out:
#    temp   yil  Aholi soni  unknown
# 0   2.3  2021        30.1      222
# 1   4.1  2020        32.4      222
# 2  42.3  2019        45.6      222
# 3   5.1  2022        98.5      222
# 4   4.5  2023        22.4      222
# 5   5.6  2009       534.5      222
# 6   7.2  2012        67.2      222

# %%
frame['unknown'] = [123,234,3545,345,345,456,243]

# %%
frame
# Out:
#    temp   yil  Aholi soni  unknown
# 0   2.3  2021        30.1      123
# 1   4.1  2020        32.4      234
# 2  42.3  2019        45.6     3545
# 3   5.1  2022        98.5      345
# 4   4.5  2023        22.4      345
# 5   5.6  2009       534.5      456
# 6   7.2  2012        67.2      243

# %%
frame.unknown = [1,2,3,4,4,5,6]

# %%
frame
# Out:
#    temp   yil  Aholi soni  unknown
# 0   2.3  2021        30.1        1
# 1   4.1  2020        32.4        2
# 2  42.3  2019        45.6        3
# 3   5.1  2022        98.5        4
# 4   4.5  2023        22.4        4
# 5   5.6  2009       534.5        5
# 6   7.2  2012        67.2        6

# %%
frame = pd.DataFrame(data, columns = ['temp', 'yil', 'Aholi soni', 'unknown'], index=[12,43,54,21,12,True,'a'])

# %%
frame
# Out:
#       temp   yil  Aholi soni unknown
# 12     2.3  2021        30.1     NaN
# 43     4.1  2020        32.4     NaN
# 54    42.3  2019        45.6     NaN
# 21     5.1  2022        98.5     NaN
# 12     4.5  2023        22.4     NaN
# True   5.6  2009       534.5     NaN
# a      7.2  2012        67.2     NaN

# %%
s = frame.temp

# %%
s
# Out:
# 12       2.3
# 43       4.1
# 54      42.3
# 21       5.1
# 12       4.5
# True     5.6
# a        7.2
# Name: temp, dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
from pandas import Series

# %%
val = Series([111,222,333], index = [12, True, 'a'])

# %%
val
# Out:
# 12      111
# True    222
# a       333
# dtype: int64

# %%
frame.unknown = val

# %%
frame
# Out:
#       temp   yil  Aholi soni  unknown
# 12     2.3  2021        30.1    111.0
# 43     4.1  2020        32.4      NaN
# 54    42.3  2019        45.6      NaN
# 21     5.1  2022        98.5      NaN
# 12     4.5  2023        22.4    111.0
# True   5.6  2009       534.5    222.0
# a      7.2  2012        67.2    333.0
