# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarjon2000/DataScience/blob/main/Midterm_exam_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read the CSV file and skip lines with parsing errors
file_path = "/Users/akbarjon/Downloads/waste.xlsx"
df = pd.read_excel(file_path, sheet_name="2017년")
df.head(10)
# Out:
#       i_day week i_food_wster_grp  i_food_wst_si t_pay_type t_discnt_yn  \
# 0  20170103    화           W6X029          50110         후불         비감면
# 1  20170103    화           W6X02A          50110         후불         비감면
# 2  20170103    화           W6X02B          50110         후불         비감면
# 3  20170103    화           W6X02C          50110         후불         비감면
# 4  20170103    화           W6X02D          50110         후불         비감면
# 5  20170103    화           W6X02E          50110         후불         비감면
# 6  20170103    화           W6X02F          50110         후불         비감면
# 7  20170103    화           W6X030          50110         후불         비감면
# 8  20170103    화           W6X031          50110         후불         비감면
# 9  20170103    화           W6X032          50110         후불         비감면
#
#    m_food_wst_cnt  m_food_wst_g  m_food_wst_amt            i_etl_dt  \
# 0              12         16950               0 2019-07-11 15:34:28
# ...

# %%
correlation_matrix = df.corr(numeric_only=True)

# %%
correlation_matrix
# Out:
#                    i_day  i_food_wst_si  m_food_wst_cnt  m_food_wst_g  \
# i_day           1.000000            NaN        0.068242      0.034251
# i_food_wst_si        NaN            NaN             NaN           NaN
# m_food_wst_cnt  0.068242            NaN        1.000000      0.941135
# m_food_wst_g    0.034251            NaN        0.941135      1.000000
# m_food_wst_amt  0.097331            NaN        0.934735      0.985204
# Y               0.011780            NaN        0.056113      0.071713
# X               0.014146            NaN        0.020984      0.023925
#
#                 m_food_wst_amt         Y         X
# i_day                 0.097331  0.011780  0.014146
# i_food_wst_si              NaN       NaN       NaN
# m_food_wst_cnt        0.934735  0.056113  0.020984
# m_food_wst_g          0.985204  0.071713  0.023925
# m_food_wst_amt        1.000000  0.061444  0.015957
# Y                     0.061444  1.000000  0.771957
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')

# Identify the top two features that depend on waste count
top_features = correlation_matrix['m_food_wst_cnt'].sort_values(ascending=False)[1:3]
print("Top two features that depend on waste count:")
print(top_features)
plt.show()
# Out:
# Top two features that depend on waste count:
# m_food_wst_g      0.941135
# m_food_wst_amt    0.934735
# Name: m_food_wst_cnt, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')

# Identify the top two features that depend on Waste amount
top_features = correlation_matrix['m_food_wst_amt'].sort_values(ascending=False)[1:3]
print("Top two features that depend on Waste amount:")
print(top_features)
plt.show()
# Out:
# Top two features that depend on Waste amount:
# m_food_wst_g      0.985204
# m_food_wst_cnt    0.934735
# Name: m_food_wst_amt, dtype: float64
